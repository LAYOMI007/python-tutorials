# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\agricultural-data.csv")

# %%
df
# Out:
#    soil_type fertilizer_type    rainfall  temperature   crop_yield  pH_level  \
# 0      Sandy          Type C   70.429560    23.039459  2077.964838  6.586590
# 1      Peaty          Type B   85.603116    17.682425  2234.546862  6.692659
# 2       Loam          Type C   90.787225    26.480601  1628.914787  6.058071
# 3      Sandy          Type C  121.142445    26.305276  1603.863016  6.576863
# 4      Sandy          Type A  106.872366    25.025567  2156.582470  6.529104
# 5      Peaty          Type C   64.739197    23.827064  2089.095402  5.928515
# 6       Loam          Type A  106.481679    17.923146  2075.147855  6.678894
# 7       Loam          Type C   92.298354    22.896773  2103.934463  6.780392
# 8      Sandy          Type C   86.461560    23.286427  1795.992584  7.041526
# 9       Clay          Type A  112.233526    20.988614  2069.676109  7.026901
# 10     Sandy          Type A  120.619990    24.193571  2087.921742  5.811165
# ...
